# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranaya42/digits-automated-speech-recognition/blob/main/speech-to-text-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install SpeechRecognition
# Out:
# ...
#      |████████████████████████████████| 32.8 MB 1.2 MB/s
# ...

# %%
#import library
import speech_recognition as sr

# Initialize recognizer class (for recognizing the speech)
r = sr.Recognizer()

# Reading Audio file as source
# listening the audio file and store in audio_text variable

with sr.AudioFile('recordings_0_jackson_23.wav') as source:
    
    audio_text = r.listen(source)
    
# recoginize_() method will throw a request error if the API is unreachable, hence using exception handling
    try:
        
        # using google speech recognition
        text = r.recognize_google(audio_text)
        print('Converting audio transcripts into text ...')
        print(text)
     
    except:
         print('Sorry.. run again...')
# Out:
# Converting audio transcripts into text ...
# 0

# %%
import zipfile
#import library
import speech_recognition as sr
#import zipfile
from zipfile import ZipFile

file_name = '/recordings.zip'

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
print(zip)
#file=zipfile.ZipFile("recordings.zip","r")
# Initialize recognizer class (for recognizing the speech)
r = sr.Recognizer()

# Reading Audio file as source
# listening the audio file and store in audio_text variable
for z in zip:
  with sr.AudioFile(z) as source:
    audio_text = r.listen(source)
    try:
        
        # using google speech recognition
        text = r.recognize_google(audio_text)
        print('Converting audio transcripts into text ...')
        print(text)
     
    except:
         print('Sorry.. run again...')
# Out:
# Done
# <zipfile.ZipFile [closed]>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-af13d11ce5a5> in <module>()
#      17 # Reading Audio file as source
#      18 # listening the audio file and store in audio_text variable
# ---> 19 for z in zip:
#      20   with sr.AudioFile(z) as source:
#      21     audio_text = r.listen(source)
#
# TypeError: 'ZipFile' object is not iterable

# %%
import zipfile
#import library
import speech_recognition as sr
import zipfile
with zipfile.ZipFile('/recordings.zip',"r") as f:
  for name in f.namelist():
    r = sr.Recognizer()
    print(name)
    with sr.AudioFile(name) as source:
      audio_text = r.listen(source)
      try:
        text = r.recognize_google(audio_text)
        print('Converting audio transcripts into text ...')
        print(text)
      except:
         print('Sorry.. run again...')
# Out:
# recordings/0_george_0.wav
# Sorry.. run again...
# recordings/0_george_1.wav
# Sorry.. run again...
# recordings/0_george_10.wav
# Converting audio transcripts into text ...
# 0
# recordings/0_george_11.wav
# Sorry.. run again...
# recordings/0_george_12.wav
# Sorry.. run again...
# recordings/0_george_13.wav
# Sorry.. run again...
# recordings/0_george_14.wav
# Sorry.. run again...
# recordings/0_george_15.wav
# Sorry.. run again...
# recordings/0_george_16.wav
# Sorry.. run again...
# recordings/0_george_17.wav
# Converting audio transcripts into text ...
# little
# recordings/0_george_18.wav
# Converting audio transcripts into text ...
# 0
# recordings/0_george_19.wav
# Converting audio transcripts into text ...
# 0
# recordings/0_george_2.wav
# Sorry.. run again...
# recordings/0_george_20.wav
# Sorry.. run again...
# recordings/0_george_21.wav
# Sorry.. run again...
# recordings/0_george_22.wav
# Sorry.. run again...
# recordings/0_george_23.wav
# Sorry.. run again...
# ...
